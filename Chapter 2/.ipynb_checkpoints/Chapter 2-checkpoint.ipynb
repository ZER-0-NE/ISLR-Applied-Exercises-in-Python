# %% [markdown]
# ### Applied Exercises

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 8. his exercise relates to the College data set, which can be found in
# the file College.csv . It contains a number of variables for 777 different
# universities and colleges in the US.

# (a) Use the read.csv() function to read the data into R . Call the loaded data college . Make sure that you have the directory set
# to the correct location for the data.

college = pd.read_csv('/home/abhishek/Desktop/ISLR-Applied-Exercises-in-Python/data/College.csv')
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
# b

# set index as first column
college = college.set_index(['Unnamed: 0'], append = True, verify_integrity=True)
# college.head()
college.rename_axis([None, 'Name'], inplace=True)
print(college.shape)
college.head()
# Out:
# (777, 18)
#                                Private  Apps  Accept  Enroll  Top10perc  \
#   Name
# 0 Abilene Christian University     Yes  1660    1232     721         23
# 1 Adelphi University               Yes  2186    1924     512         16
# 2 Adrian College                   Yes  1428    1097     336         22
# 3 Agnes Scott College              Yes   417     349     137         60
# 4 Alaska Pacific University        Yes   193     146      55         16
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
#   Name
# 0 Abilene Christian University         52         2885          537      7440
# 1 Adelphi University                   29         2683         1227     12280
# 2 Adrian College                       50         1036           99     11250
# 3 Agnes Scott College                  89          510           63     12960
# 4 Alaska Pacific University            44          249          869      7560
#
# ...

# %%
# c (i) Use the summary() function to produce a numerical summary of the variables in the data set.

college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
# (ii) Use the pairs() function to produce a scatterplot matrix of the first ten columns or variables of the data. Recall that
# you can reference the first ten columns of a matrix A using A[,1:10] 

sns.pairplot(college.iloc[:,1:11])

# %%
# (iii) Use the plot() function to produce side-by-side boxplots of Outstate versus Private .#

sns.boxplot(x = college['Private'], y = college['Outstate'])

# %%
# (iv) Create a new qualitative variable, called Elite , by binning the Top10perc variable. We are going to divide universities
# into two groups based on whether or not the proportion
# of students coming from the top 10 % of their high school
# classes exceeds 50 %.

college['Elite'] = np.where(college['Top10perc'] > 50, 'Yes', 'No')
college.head()
# Out:
#                                Private  Apps  Accept  Enroll  Top10perc  \
#   Name
# 0 Abilene Christian University     Yes  1660    1232     721         23
# 1 Adelphi University               Yes  2186    1924     512         16
# 2 Adrian College                   Yes  1428    1097     336         22
# 3 Agnes Scott College              Yes   417     349     137         60
# 4 Alaska Pacific University        Yes   193     146      55         16
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
#   Name
# 0 Abilene Christian University         52         2885          537      7440
# 1 Adelphi University                   29         2683         1227     12280
# 2 Adrian College                       50         1036           99     11250
# 3 Agnes Scott College                  89          510           63     12960
# 4 Alaska Pacific University            44          249          869      7560
#
# ...

# %%
college['Elite'].value_counts()
# Out:
# No     699
# Yes     78
# Name: Elite, dtype: int64

# %%
elite_colleges = college[college['Elite'] == 'Yes']
elite_colleges.head()
# Out:
#                                Private  Apps  Accept  Enroll  Top10perc  \
#    Name
# 3  Agnes Scott College             Yes   417     349     137         60
# 16 Amherst College                 Yes  4302     992     418         83
# 37 Barnard College                 Yes  2496    1402     531         53
# 54 Birmingham-Southern College     Yes   805     588     287         67
# 60 Bowdoin College                 Yes  3356    1019     418         76
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
#    Name
# 3  Agnes Scott College                 89          510           63     12960
# 16 Amherst College                     96         1593            5     19760
# 37 Barnard College                     95         2121           69     17926
# 54 Birmingham-Southern College         88         1376          207     11660
# 60 Bowdoin College                    100         1490            8     19030
#
# ...

# %%
# (v) Use the hist() function to produce some histograms with differing numbers of bins for a few 
# of the quantitative variables.

college['Enroll'] = pd.cut(college['Enroll'], bins = 3, labels = ['High', 'Medium', 'Low'])
college['PhD'] = pd.cut(college['PhD'], bins=5, labels = ['Very Low', 'Low', 'Medium', 'Very High', 'High'])
college['Terminal'] = pd.cut(college['Terminal'], bins = 4, labels = ['Very Low', 'Low', 'High', 'Very High'])

# %%
fig = plt.figure()

plt.subplot(221)
college['Enroll'].value_counts().plot.bar(title = 'Enroll')

plt.subplot(222)
college['PhD'].value_counts().plot.bar(title = 'PhD')

plt.subplot(223)
college['Terminal'].value_counts().plot.bar(title = 'Terminal')

fig.subplots_adjust(hspace=1)
